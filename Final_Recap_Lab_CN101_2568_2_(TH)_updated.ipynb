# %% [markdown]
# <a href="https://colab.research.google.com/github/yongsa-nut/TU_CN101_68-2/blob/main/Final_Recap_Lab_CN101_2568_2_(TH)_updated.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Final Lab (TH)

# %% [markdown]
# **ชื่อ-นามสกุล ภาษาอังกฤษตามที่ปรากฎบน MS Teams**

# %% [markdown]
# **Q1**: จงเขียนผลลัพท์ของโปรแกรมต่อไปนี้
#
# ```python
# my_list = [10, 50, 30, 5, 7]
# your_list = [num*2 for num in my_list]
# print(min(your_list), max(your_list))
# ```

# %% [markdown]
# **Q2**: จงเขียนผลลัพท์ของโปรแกรมต่อไปนี้
#
# ```python
# jobs = ['Engineer','Accountant','Doctor']
# print(sum([len(job) for job in jobs]))
# ```

# %% [markdown]
# **Q3**: จงเขียนผลลัพท์ของโปรแกรมต่อไปนี้
#
# ```python
# list1 = "aa bb cc".split()
# list1.append("xx")
# list1[0] = "k"
# print(list1)
# ```

# %% [markdown]
# **Q4**: จงเขียนผลลัพท์ของโปรแกรมต่อไปนี้
#
# ```python
# temp = "10:20"
# words = temp.split(":")
# first = int(words[0])
# second = int(words[1])
# print(first+second)
# ```

# %% [markdown]
# **Q5**: จงเขียนผลลัพท์ของโปรแกรมต่อไปนี้
#
# ```python
# def do_something(total, rate=0.8):
#     return total+5*rate
#
# print(do_something(10)+do_something(10,0.1)*2)
# print(do_something(rate=0.3, total=5))
# ```

# %% [markdown]
# **Q6**: จงเขียนผลลัพท์ของโปรแกรมต่อไปนี้
#
# ```python
# my_string = "Hello"
#
# def do_another():
#     my_string = "Hello There"
#     my_string = my_string[7:]
#     print(my_string, end='')
#
# do_another()
# do_another()
# print(my_string)
# ```

# %% [markdown]
# **Q7**: จงเติมคำในช่องว่างเพื่อให้โปรแกรมแสดงผลเป็น `AT MEOW`

# %%
cat = "Dog"
dog = "Cat"
text = cat + " " + dog + " Meow"
text = text.upper()
print(text[_____________])

# %% [markdown]
# **Q8**: จงเขียนผลลัพท์ของโปรแกรมต่อไปนี้
#
# ```python
# my_dict = {'Alice':10, 'Bob':20, 'Chris':30}
# my_dict['Pat'] = 50
# my_dict['Alice'] = 99
# print(my_dict)
# ```

# %% [markdown]
# **Q9**: จงเขียนผลลัพท์ของโปรแกรมต่อไปนี้
#
# ```python
# scores = {"Bob":23, "Big": 22, "bat":20, "Kate":17}
# total = 0
# for key, value in scores.items():
#     if (key[0].lower() == 'b') and (value%2==0):
#         total+= value
# print(total)
# ```

# %% [markdown]
# **Q10**: จงเขียนผลลัพท์ของโปรแกรมต่อไปนี้
#
# ```python
# my_list   = [2, 5, 3, 6]
# your_list = [my_list[i] for i in range(len(my_list)) if my_list[i]%2==0]
# for num in your_list:
#   my_list.append(num)
# print(my_list)
# print(my_list[-1]+len(my_list))
# ```

# %% [markdown]
# **Q11**: จงเขียนผลลัพท์ของโปรแกรมต่อไปนี้
#
# ```python
# bs = {'A':1, 'B':2, 'C':3}
# x = sum(bs.values())
# t = sum(v for v in bs.values() if v%2==1)
# if x == t:
#   print('yes')
# else:
#   print('no')
# ```

# %% [markdown]
# **Q12**: Circle Properties
#
# จงเขียนฟังก์ชัน `circle_properties(radius)` ที่รับค่ารัศมีของวงกลมและคืนค่าพื้นที่และเส้นรอบวงของวงกลม
#
#
# **Input** (in `main`):
# - จำนวนจริง รัศมีที่รับจากผู้ใช้
#
# **Output** (in `main`):
# - จำนวนจริง พื้นที่ของวงกลมแสดงทศนิยม 2 ตำแหน่ง
# - จำนวนจริง เส้นรอบวงแสดงทศนิยม 2 ตำแหน่ง
#
# **Note**:
# - ใช้ค่า pi จาก math library
#
# Example 1:
#
# ```
# Enter the radius: 1
# Area: 3.14
# Circumference: 6.28
# ```
#
# Example 2:
# ```
# Enter the radius: 2.5
# Area: 19.63
# Circumference: 15.71
# ```

# %%
# import
_____________________________

# Implement circle_properties(radius) function here
# Argument: radius
# Returns: area and circumference
def circle_properties(radius):
    area = ____________________
    circum = __________________
    ___________________________

def main():
    radius = float(input("Enter the radius: "))
    # call circle_properties(radius) below
    ____________________________
    # print area and circumference
    ____________________________
    ____________________________

main()

# %% [markdown]
# **Q13**: Step counts
#
# จงเติมโค็ดในกระดาษคำตอบ เพื่อทำให้โปรแกรมสมบูรณ์ โดยโปรแกรมรับรายการตัวเลขจากผู้ใช้ (โดยบางรายการอาจเป็นคำ เช่น ten, twenty, five ซึ่งต้องข้ามไป ไม่นำมาคำนวณ) แล้วคำนวณค่าเฉลี่ย หาตำแหน่งของค่าที่มากที่สุด และตำแหน่งของค่าที่น้อยที่สุด
#
# **ข้อกำหนดเกี่ยวกับฟังก์ชั่น**:
# - get_input(): รับข้อความที่เป็นรายการคั่นด้วย `:` จากผู้ใช้ เช็คแต่ละรายการด้วย `.isdigit()` ก่อน ถ้าเป็นตัวเลขจริงค่อยแปลงเป็น `int` แล้ว append เข้าลิสต์ สุดท้าย return ลิสต์ของตัวเลขที่ผ่านการกรอง
# - analyze(numbers): ส่งค่าเฉลี่ย, index ของค่าที่มากที่สุด และ index ของค่าที่น้อยที่สุด ออกมาตามลำดับ (ถ้ามีค่าซ้ำ เลือกตัวสุดท้ายที่เจอ)
# - print_answer(numbers, avg, max_i, min_i): แสดงผล 3 บรรทัด โดยเลขตำแหน่ง (Position) เริ่มนับจาก 1 และค่าเฉลี่ยเป็นทศนิยม 2 ตำแหน่ง
# main(): เรียกใช้งานฟังก์ชั่นอื่นๆตามลำดับ
#
# **Input**:
#   - รับข้อความ 1 บรรทัด เป็นรายการคั่นด้วย `:` (อย่างน้อย 1 รายการที่เป็นตัวเลข)
# **Output**:
#   - แสดงผล 3 บรรทัดตามฟังก์ชั่น print_answer
#
# ตัวอย่างการรันที่ 1:
# ```
# Enter numbers: 10:twenty:30:40:fifty
# Average: 26.67
# Highest: Position 3 (40)
# Lowest: Position 1 (10)
# ```
# ตัวอย่างการรันที่ 2:
# ```
# Enter numbers: 100:200:300
# Average: 200.00
# Highest: Position 3 (300)
# Lowest: Position 1 (100)
# ```
# ตัวอย่างการรันที่ 3:
# ```
# Enter numbers: 5:four:8:3:two:10:seven
# Average: 6.50
# Highest: Position 4 (10)
# Lowest: Position 3 (3)
# ```

# %%
def get_input():
    input_string = _________________________________
    raw = __________________________________________
    numbers = []
    for item in raw:
        if ________________________________________:
            item = ________________________________  # string to int
            numbers.append(____________________)
    return numbers

def analyze(numbers):
    avg = ___________________________________________

    max_i = 0
    min_i = 0
    for i in range(len(numbers)):
        if numbers[i] == max(numbers):
            max_i = i
        if _____________________________________:
            min_i = i

    ____________________________________________________

def print_answer(numbers, avg, max_i, min_i):
    print(___________________________________________)
    print(___________________________________________)
    print(___________________________________________)

def main():
    numbers = get_input()
    _______________________________________________
    _______________________________________________

main()

# %% [markdown]
# **Q14**: String to a list of squared numbers
#
# จงสร้างฟังก์ชัน `get_query` ที่ถามผู้ใช้สำหรับลำดับของตัวเลขที่คั่นด้วย `//` หลังจากนั้นให้ส่งลิสต์ของตัวเลขยกกำลังสองออกมา โดยที่ List นั้นจะต้องต้องผ่านสองเงื่อนไขนี้:
#
# 1) มีความยาวไม่เกิน 5
# 2) ตัวเลขหลังยกกำลังแล้วต้องมีค่าไม่เกิน 100
#
# โดยที่ในการเช็คนั้นจะต้องเรียกใช้ฟังก์ชัน `is_valid_sequence` เพื่อตรวจสอบทั้งสองเงื่อนไขด้านบน
#
# **Pseudocode**:
#
# 1. `is_valid_sequence(sequence)`: ฟังก์ชันจะรับ ลิสต์ของตัวเลข แล้วส่งคืน True ถ้าลิสต์นั้นตรงตามเงื่อนไขทั้งสองอัน ส่งคืน False ถ้าผิดอันใดอันหนึ่ง
# 2. `get_query()`: ฟังก์ชันจะรับค่าจากผู้ใช้งาน แล้วเปลี่ยนจาก string ให้กลายเป็น ลิสต์ของตัวเลขยกกำลังสอง หลังจากนั้น จึงเรียกใช้ `is_valid_sequence` เพื่อตรวจสอบ ถ้าเป็นจริง ให้ส่งคืน ลิสต์ที่ได้ ถ้าไม่เป็นจริง ให้แสดงผลว่า "Invalid" และ ให้ส่งคืน None
# 3. `main()`: ฟังก์ชั่น main จะเรียกใช้ `get_query()` ใน while loop ถ้า ผลที่ได้ออกมาไม่เป็น None ให้ break ออกจากลูปแล้วแสดงผล ถ้าเป็น None ให้เรียกใช้ `get_query()` ต่อไปเรื่อย
#
#
# **Input**:
# - สตริง ซึ่งเป็นลำดับของตัวเลขที่คั่นด้วย `//`
#
# **Output**:
# - ลิสต์ของตัวเลข
#
# **ข้อกำหนด**:
# - ต้องใช้ Named Constant
#
# Example 1:
# ```
# Enter numbers: 10//20//30
# The sequence is [100, 200, 300] and it's invalid.
# Enter numbers: 5//10
# A valid sequence: [25, 100]
# ```
#
# Example 2:
# ```
# Enter numbers: 5//10//1//2//3//4
# The sequence is [25, 100, 1, 4, 9, 16] and it's invalid.
# Enter numbers: 1//2//3//4
# A valid sequence: [1, 4, 9, 16]
# ```

# %%
# Named Constant
MAX_LENGTH = 5

def is_valid_sequence(sequence):
    if ________________:
        return False
    for num in sequence:
        if _______________
            ______________
    # ออกจากลูปแสดงว่าทุกตัวไม่เกิน 100
    return ____________

def get_query():
    seq = input('Enter numbers: ')
    # Fill in your code below
    str_list = _________________________
    squared_list = []  # ลิสต์สำหรับเก็บตัวเลขยกกำลังสอง
    for num_str in str_list:
        num = ___________________
        _____________________________ # เพิ่มตัวเลขยกกำลังสองเข้าไปในลิสต์
    if __________________________
        _________________________
    else:
        _________________________
        return None

def main():
    while True:
        your_list = get_query()
        if __________________________:
            break
    print(f'A valid sequence: {your_list}')

main()

# %% [markdown]
# **Q15**: Linear function
#
# ในข้อนี้เราจะสร้าง Data ขึ้นมาสองชุด `X` และ `Y` โดยที่ ในแต่ละ `y` จะมีค่าเท่ากับ `y = w*x+b` (เส้นตรง) โดยที่ ค่า `w` กับ `b` จะรับมาจากผู้ใช้งาน และค่า `x` จะเกิดจากการสุ่มตัวเลขจำนวนเต็มระหว่าง 1 ถึง 8
#
# หลังจากสร้างข้อมูลเสร็จให้หา ค่าผลรวมของ ข้อมูลทั้งหมดยกกำลังสอง ของทั้ง X และ Y และผลต่างของ ค่าผลรวมทั้งสองอันนั้น และแสดงผลทั้งสามค่าออกมา
#
# ฟังก์ชันที่ต้องเขีนนมีดังต่อไปนี้
#
# **gen_data(w, b, n)**: ฟังก์ชั่นสำหรับสร้างข้อมูล `X` และ `Y`
# - สร้าง list ว่างเปล่า ชื่อ `X`
# - สร้าง list ว่างเปล่า ชื่อ `Y`
# - ทำการวนลูปจำนวน `n` ครั้ง
#   - สร้างตัวแปร `x` มาเก็บตัวเลขที่สุ่มระหว่าง 1 ถึง 8 ไว้
#   - คำนวณ `y` ตามฟังก์ชันเชิงเส้น `y = w*x + b`
#   - เพิ่ม `x` เข้า `X`
#   - เพิ่ม `y` เข้า `Y`
# - คืนค่า `X` และ `Y`
#
# **sum_squared_diff(X,Y)**: ฟังก์ชั่นสำหรับหาผลรวมยกกำลังสองของ X, Y และหาผลต่างของผลรวมยกกำลังสอง
# - สร้างตัวแปร `total_X` แล้วตั้งค่าเป็น 0
# - สร้างตัวแปร `total_Y` แล้วตั้งค่าเป็น 0
# - วนลูป i จาก 0 ถึง จำนวนตัวเลข/ความยาวของ X :
#   - บวกค่าของ `X[i]` ยกกำลังสอง เข้าไปใน `total_X`
#   - บวกค่าของ `Y[i]` ยกกำลังสอง เข้าไปใน `total_Y`
# - ส่งค่ากับสามค่า `total_X`, `total_Y`, ผลต่างของ `total_X` กับ `total_Y`
#
# **ฟังก์ชัน: main()**
# - ตั้งค่า random seed เป็น 100
# - รับค่า `w`, `b`, `n` จากผู้ใช้
# - เรียกใช้ `gen_data` ด้วย `w`, `b` และ `n` เพื่อสร้างข้อมูล `X` และ `Y`
# - เรียกใช้ `sum_squared_diff` ด้วยค่า `X` และ `Y` และเก็บคำตอบสามค่าที่ได้ไว้ในตัวแปร `X_ss`, `Y_ss`, `XY_diff`
# - แสดงผลค่า `X_ss`, `Y_ss`, `XY_diff` ตามตัวอย่างด้านล่าง
#
# **หมายเหตุ**:
# - ต้องทำตาม Pseudocode
#
# Example 1:
#
# ```
# Enter w: 2
# Enter b: 3
# Enter n: 5
# SSX = 195, SSY = 1173.0, Diff = -978.0
# ```
#
# Example 2:
#
# ```
# Enter w: -2
# Enter b: 1
# Enter n: 3
# SSX = 137, SSY = 475.0, Diff = -338.0
# ```

# %%
# import
___________________________


def gen_data(w, b, n):
    _______________________
    _______________________
    _______________________
    _______________________
    _______________________
    _______________________
    _______________________
    _______________________

def sum_squared_diff(X,Y):
    _______________________
    _______________________
    _______________________
    _______________________
    _______________________
    _______________________

# implement main function
def main():
    random.seed(100)
    w = float(input('Enter w: '))
    b = float(input('Enter b: '))
    n = int(input('Enter n: '))
    _______________________________________
    _______________________________________
    _______________________________________

main()
