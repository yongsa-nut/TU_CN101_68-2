# %% [markdown]
# <a href="https://colab.research.google.com/github/yongsa-nut/TU_CN101_68-2/blob/main/List_Lab_2568_2_(TH).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # List 2 Lab (TH)

# %% [markdown]
# Turn off AI: Tools -> Settings -> Hide generative AI features

# %% [markdown]
# **Q1**:  What will this program print out?
#
# ```python
# temp = [5,5,4,4,4,3,3]
# temp[0] = 1
# temp[1] = len(temp)
# temp[len(temp)-1] = temp[0]*2
# print(temp)
# ```

# %% [markdown]
# **Q2**: What will this program print out?
# ```python
# seq1 = [1,2,3]
# seq2 = [4,4,4]
# seq3 = seq1 + seq2
# seq3[4] = 5
# print(seq3)
# ```

# %% [markdown]
# **Q3** What will this program print out?
# ```python
# seq1 = [0]*5
# seq2 = [1,2,3]*3
# print(seq1 + seq2)
# ```

# %% [markdown]
# **Q4**: What will this program print out?
#
# ```python
# target = 'E'
# if target in ['A','B','C']:
#     print([target]*1)
# elif target in ['A','D','FE']:
#     print([target]*2)
# elif target in ['A','E','I','O','U']:
#     print([target]*3)
# else:
#     print([target]*4)
# ```

# %% [markdown]
# **Q5**: What will this program print out if the user enters `122`?
#
# ```python
# references = [12,234,671,32,122,99]
# query = int(input('Enter your query'))
# if query in references:
#     print('Yes')
# else:
#     print('No')
# ```

# %% [markdown]
# **Q6**: What will this proram print out?
#
# ```python
# my_list = [0, 1, 2]
# my_list.append(5)
# my_list.append(7)
# print(my_list)
# my_list.append(my_list[0] + my_list[-1])
# print(my_list)
# ```

# %% [markdown]
# **Q7**: What will this program print out?
#
# ```python
# temp = [30,20,18,90,77,44]
# new_list = []
# for num in temp:
#     if num > 20:
#         new_list.append(num)
# print(new_list)
# ```

# %% [markdown]
# **Q8**: What will this program print out?
# ```python
# initial = [1,1]
# for i in range(1,5):
#     initial.append(initial[i-1] + initial[i])
# print(initial)
# ```

# %% [markdown]
# **Q9**: What will this program print out?
# ```python
# names = [['Alice','Bob'],['Anna','Mike'],['Mary','Richard']]
# print(names[0][1], names[2][0])
# ```

# %% [markdown]
# **Q10**: What will this program print out?
# ```python
# numbers = [[1, 2, 3],
#            [3, 4, 5],
#            [0, 1, 2]]
# total = numbers[0][1] + numbers[1][0]*numbers[2][2]
# print(total)
# ```

# %% [markdown]
# **Q11:** What will the following code print out?
#
# ```python
# numbers = [7, 8, 25, 20, 25]
# numbers.insert(3, 10)
# numbers.sort()
# numbers.remove(25)
# print(numbers)
# ```

# %% [markdown]
# **Q12**: What will the following code print out?
#
# ```python
# numbers = [10, 30, 50, 8]
# highest = max(numbers)
# lowest = min(numbers)
# total = sum(numbers)
# print(total, lowest, highest)
# ```

# %% [markdown]
# **Q13**: What will the following code print out?
# ```python
# seqs = [2, 7, 9, 10]
# n = len(seqs)
# mean = sum(seqs)/n
# for i in range(n):
#     seqs[i] = seqs[i] - mean
# print(seqs)
# ```

# %% [markdown]
# **Q14**: What will the following code print out?
#
# ```python
# items = [1, 2, 3, 4]
# list1 = [item+1 for item in items]
# list2 = [item**2 for item in items if item%2 ==0]
# print(list1)
# print(list2)
# ```

# %% [markdown]
# **Q15**: What will the following code print out?
# ```python
# my_list = [5, 2, 7, 1]
# list1 = sorted(my_list, reverse = True)
# list2 = sorted(my_list, reverse = False)
# print(my_list)
# print(list1)
# print(list2)
# ```

# %% [markdown]
# **Q16** Fill in the blank so that the program prints out `[2,4,6,8]`

# %%
my_list = []
for num in range(1,10):
    if ______________________:
        ______________________
print(my_list)

# %% [markdown]
# **Q17** Fill in the blank so that the program prints out `[1, 4, 9, 16]`

# %%
numbers = [0, 1, 2, 3]
print([___________ for ______ in numbers])

# %% [markdown]
# **Q18** Fill in the blank so that the program print out `[5, 10, 15]` (เฉพาะตัวเลขที่หารห้าลงตัว)

# %%
sequences = [1, 5, 10, 3, 15, 4, 7, 9]
new_list = [_____ for ______ in sequences __________________________]
print(new_list)

# %% [markdown]
# **Q19**: Create a list from the user
#
# จงเขียนโปรแกรม เพื่อรับข้อมูลนำเข้าจาก user และมาสร้างเป็น list. User จะพิมพ์ค่า `n` ก่อนแล้วหลังจากนั้นจะพิมพ์ข้อมูล จำนวนเต็มอีก `n` ค่า
#
# หลังจากนั้น ให้หาค่า ค่าเฉลี่ยของ list และ สร้าง list อีก list ที่ลบค่าเฉลี่ยออกจากจำนวนทุกค่า
#
# **Extra**: เขียนสองโปรแกรม: 1) using `append`, 2) list comprehension
#
# **Hint**: สามารถใช้ `sum()`
#
# Example 1:
# ```
# Enter n: 3
# Enter number: 1
# Enter number: 1
# Enter number: 1
# The original list is [1, 1, 1]
# The mean is 1.00
# The new list is [0.0, 0.0, 0.0]
# ```
#
# Example 2:
#
# ```
# Enter n: 5
# Enter number: 1
# Enter number: 3
# Enter number: 5
# Enter number: 7
# Enter number: 9
# The original list is [1, 3, 5, 7, 9]
# The mean is 5.00
# The new list is [-4.0, -2.0, 0.0, 2.0, 4.0]
# ```

# %%
# Using Append

# %%
# Extra: Using List comprehension

# %% [markdown]
# **Q20**: FizzBuzz
#
# จงเขียนโปรแกรมที่จะรับตัวเลขจำนวนเต็ม $n$ และแสดงผลลิสต์ (`answer`) ของตัวเองที่มีลักษณะดังต่อไปนี้ :
#
# * $\texttt{answer[i] == "FizzBuzz"}$ ถ้า $\texttt{i}$ หารด้วย 3 และ 5 ลงตัว
# * $\texttt{answer[i] == "Fizz"}$ ถ้า $\texttt{i}$ หารด้วย 3 ลงตัวอย่างเดียว
# * $\texttt{answer[i] == "Buzz"}$ ถ้า $\texttt{i}$ หารด้วย 5 ลงตัวอย่างเดียว
# * $\texttt{answer[i] == i}$ ถ้าเงื่อนไขด้านบนไม่ถูกเลย
#
#
# Example 1:
#
# ```
# Enter n: 3
# [1, 2, 'Fizz']
# ```
#
# Example 2:
#
# ```
# Enter n: 5
# [1, 2, 'Fizz', 4, 'Buzz']
# ```
#
# Example 3:
#
# ```
# Enter n: 15
# [1, 2, 'Fizz', 4, 'Buzz', 'Fizz', 7, 8, 'Fizz', 'Buzz', 11, 'Fizz', 13, 14, 'FizzBuzz']
# ```

# %% [markdown]
# ## Submission
# - File -> Download -> Download .ipynb
# - Upload to MS Teams
