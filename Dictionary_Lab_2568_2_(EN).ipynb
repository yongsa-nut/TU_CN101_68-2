# %% [markdown]
# <a href="https://colab.research.google.com/github/yongsa-nut/TU_CN101_68-2/blob/main/Dictionary_Lab_2568_2_(EN).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Dictionary Lab (EN)

# %% [markdown]
# **Turn off AI**
#
# Tools > Setting > AI Assistance > Check Hide generative AI features

# %% [markdown]
# **Q1**: What will the following program print out?
#
# ```python
# my_dict = {'Mary':1,'Mathil':2,'Mona':3}
# print(my_dict['Mary'] + 2*my_dict['Mona'])
# ```

# %% [markdown]
# **Q2**: What will the following program print out?
#
# ```python
# dict1 = {'A':1,'B':2,'C':3}
# dict1['A'] = 3
# dict1['B'] = dict1['C']
# dict1['Z'] = 5
# print(dict1)
# ```

# %% [markdown]
# **Q3**: What will the following program print out?
#
# ```python
# my_dict = {'AAA': 'aaa', 'BBB':'bbb', 'ABB':'abb', 'CBA':'cba', 'abc':'ABC'}
# target = 'ABC'
# if target in my_dict:
#     print('Yes')
# else:
#     print('No')
# ```

# %% [markdown]
# **Q4**: What will the following program print out?
#
# ```python
# my_dict = {'A':2,'B':5,'C':7,'D':10}
# total = 0
# for key in my_dict:
#     total += my_dict[key]
# print(total)
# ```

# %% [markdown]
# **Q5**: What will the following program print out?
#
# ```python
# my_dict = {'A':1,'B':2,'C':6,'D':8,'E':7}
# total = 1
# for key, value in my_dict.items():
#     if value % 2 == 0:
#         total *= 2
#     else:
#         total *= value
# print(total)
# ```

# %% [markdown]
# **Q6**: What will the following program print out?
#
# ```python
# new_dict = {'2023':[],'2024':[]}
# new_dict['2023'].append(1)
# new_dict['2024'].append(10)
# new_dict['2022'] = ['A','B','C']
# print(new_dict)
# ```

# %% [markdown]
# **Q7**: What will the following program print out?
#
# ```python
# sentences = "Cat cat dog cat dog Meow meow cat cat meow"
# sentences = sentences.upper()
# words = sentences.split()
# my_dict = {}
# for word in words:
#     my_dict[word] = my_dict.get(word,0) + 1
# print(my_dict)
# ```

# %% [markdown]
# **Q8**: Fill in the blank so that it prints out ``11``.

# %%
my_dict = {'A': 1, 'B': 11, 'C': 111}
print(my_dict[__])

# %% [markdown]
# **Q9**: Fill in the blank so that the program prints out `12`

# %%
our_dict = {'A':'1','B':'2','C':10,'D':5}
print(our_dict[____] + our_dict[____])

# %% [markdown]
# **Q10**: Fill in the blank so that it prints out `30`.

# %%
dict_list = {'Math':[10, 20, 30],
             'Science':[40, 50, 60],
             'English':[70, 80, 90]}

print(dict_list[__][__])

# %% [markdown]
# **Q11**: Fill in the blank so that it prints out `A`.

# %%
users = {'Mary':{'age':20, 'gender':'F','grade':'B'},
         'John':{'age':30, 'gender':'M','grade':'A'},
         'Bob':{'age':25, 'gender':'M','grade':'C'}}

print(users[__][__])

# %% [markdown]
# **Q12** Fill in the blanks so that the program print out `{'Anna': [30, 20], 'Bob': []}`

# %%
scores = {'Anna':[],'Bob':[]}
scores['Anna'].____________
scores['Anna'].____________
print(scores)

# %% [markdown]
# **Q13**: Fill in the code in the function `print_sum` so that the program displays the sum of payments for each person from the dictionary provided in `main` as shown below.
#
# ```
# First Payment
# Anna: 30
# Bob: 140
# Second Payment
# Alice: 120
# Chris: 150
# Mike: 10
# ```

# %%
def print_sum(payments):
    for key in payments:
        _____________________________________

def main():
    first = {'Anna':[10,20],
            'Bob':[20,30,40,50]
            }
    second = {'Alice':[30, 40, 50],
              'Chris':[50,100],
              'Mike':[10]
              }
    print('First Payment')
    print_sum(first)
    print('Second Payment')
    print_sum(second)

main()

# %% [markdown]
# **Q14**: Count vowels
#
# Create a dictionary to count the number of vowels (a, e, i, o, u) from the input.
#
# **Input**
# - string
#
# **Output**
# - A dictionary
#
# **Notes:**
# - Fill in the code in the function `count_vowels(input_string)` which receives a string and returns a dictionary
# - Fill in the code in the function `main()` which receives text from the user, calls `count_vowels(input_string)`, and prints the result
# - The order of keys in the displayed dictionary does not need to match the example
#
#
# **Example 1**
#
# ```
# Enter input string: AaA eE i o uUuu
# {'a': 3, 'e': 2, 'i': 1, 'o': 1, 'u': 4}
# ```
#
# **Example 2**
#
# ```
# Enter input string: Hello How are you? I'm fine thank you.
# {'a': 2, 'e': 3, 'i': 2, 'o': 4, 'u': 2}
# ```

# %%
def count_vowels(input_string):
    # Description: a function to create a dictionary of words and their counts
    # Args: input_string - text
    # Returns: a dictionary


def main():
    user_input = input("Enter input string:")


main()

# %% [markdown]
# **Q15**: Dictionary of even and odd
#
#
# Write a program that receives input from the user, where the input is numbers separated by commas. Then create a dictionary containing two lists to store even numbers and odd numbers from the input, as shown in the examples below.
#
# **Input**:
# - A string
#
# **Output**:
# - A dictionary
#
# **Notes**:
# - The `dict_even_odd(input_string)` function receives a string and returns a dictionary as shown in the examples
# - `main()` receives input from the user as multiple numbers separated by commas, then calls `dict_even_odd(input_string)` and stores the result in a variable, and prints that variable
#
#
# **Example 1**:
# ```
# Enter input string: 1
# {'even': [], 'odd': [1]}
# ```
#
# **Example 2**:
# ```
# Enter input string: 1,3,5,8,10
# {'even': [8, 10], 'odd': [1, 3, 5]}
# ```
#
# **Example 3**:
# ```
# Enter input string: 0,4,7,9,12
# {'even': [0, 4, 12], 'odd': [7, 9]}
# ```

# %%
def dict_even_odd(input_string):
    # A function to create a dict of even/odd lists
    # Args: input_string - a string of numbers separated by commas
    # Returns: A dict


def main():



main()
