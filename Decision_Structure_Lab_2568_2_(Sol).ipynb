# %% [markdown]
# <a href="https://colab.research.google.com/github/yongsa-nut/TU_CN101_68-2/blob/main/Decision_Structure_Lab_2568_2_(Sol).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Decision Structure Lab (EN)

# %% [markdown]
# Turn off AI: Tools -> Settings -> Hide generative AI features

# %% [markdown]
# **Q1**: What will the program print out?
#
# ```python
# a = 30
# b = 20
# c = 40
# print((a != b) or (b > c))
# print((c > b) and (a > b))
# ```

# %%
True
True

# %% [markdown]
# **Q2**: What will the program print out?
# ```python
# x = 5
# if x > 3:
#     print("Hello")
# else:
#     print("Goodbye")
# ```

# %%
Hello

# %% [markdown]
# **Q3**: What will the program print out?
# ```python
# age = 18
# if age >= 18:
#     print("You can vote")
#
# if age >= 30:
#     print("You are old")
# else:
#     print("You are young")
#
# print('Done')
# ```

# %%
You can vote
You are young
Done

# %% [markdown]
# **Q4**: What will the program print out?
# ```python
# score = 75
# if score >= 90:
#     print("A")
# elif score >= 80:
#     print("B")
# elif score >= 70:
#     print("C")
# else:
#     print("F")
# ```

# %%
C

# %% [markdown]
# **Q5**: What will the program print out?
# ```python
# score = 95
# if score >= 90:
#     print("A")
# if score >= 80:
#     print("B")
# if score >= 70:
#     print("C")
# else:
#     print("F")
# ```

# %%
A
B
C

# %% [markdown]
# **Q6**: What will the program print out?
#
# ```python
# a = 5
# b = 3
# c = 7
# if a > b and a > c:
#     print("A is largest")
# elif b > a and b > c:
#     print("B is largest")
# else:
#     print("C is largest")
# ```

# %%
C is largest

# %% [markdown]
# **Q7**: What will the followign code print out?
#
# ```python
# x = 30
# if x > 50:
#     print("A")
# elif x > 40:
#     print("B")
# elif x > 30:
#     print("C")
# else:
#     print("D")
# ```

# %%
D

# %% [markdown]
# **Q8**: What will the following code print out?
# ```python
# x = 5
# y = 7
# z = 10
# print(f"{x > z}, {z < y}, {x*2 == (y+z)}, {(x+z) != (1+y*2)}")
# ```

# %%
False, False, False, False

# %% [markdown]
# **Q9**: What will the following code print out?
# ```python
# value = 52
# if value > 45:
#     print("First", end='')
# if value > 40:
#     print("Second", end='')
# if value > 35:
#     print("Third", end='')
# else:
#     print("Fourth", end='')
# ```

# %%
FirstSecondThird

# %% [markdown]
# **Q10**: What will the following code print out?
# ```python
# name = 'Alice'
# value = 10
# if name == 'Anna':
#     print('Hello', end = ',')
#     if value > 20:
#         print('Big', end='-')
#     else:
#         print('Small', end='-')
# else:
#     print('Hi', end = ':')
#     if value < 15:
#         print('Yes', end='-')
#     else:
#         print('NO', end='-')
# print('Done')
# ```

# %%
Hi:Yes-Done

# %% [markdown]
# **Q11**: Fill in the code to make the program display ```Hello``` if ```x``` is greater than or equal to 5

# %%
x = 7
if x > 5:
    print("Hello")

# %% [markdown]
# **Q12**: Fill in the code to display ```Pass``` if the score is greater than or equal to 60, otherwise display ```Fail```

# %%
score = 75
if score >= 60:
    print("Pass")  #here
else:
    print("Fail")  #here

# %% [markdown]
# **Q13**: Fill in the code to check if the number (num) is divisible by both 2 and 3

# %%
num = 12
if num % 2 == 0 and num % 3 == 0:
    print("Divisible by 2 and 3")

# %% [markdown]
# **Q14**: Fill in the code to display "Child" if age is less than 13, "Teen" if age is between 13 and 19, and "Adult" if greater than 19:

# %%
age = 15
if age < 13:
    print("Child")
elif 13 <= age and age <= 19:
    print("Teen")
else:
    print("Adult")

# %% [markdown]
# **Q15**: Fill in a number so that the program displays 'Here'. (There are multiple answers)

# %%
num = 12 # here
if num > 19 and num < 9:
    print('Not here')
elif num <7:
    print('Not here')
elif num > 15:
    print('Not here')
else:
    print('here')
# Out:
# here

# %% [markdown]
# **Q16**: Fill in a number so that the program displays ```2```

# %%
x = 5
y = 7
z = 2   # here
if x < y:
    if y < z:
        print("1")
    else:
        print("2")
else:
    if x < z:
        print("3")
    else:
        print("4")
# Out:
# 2

# %% [markdown]
# **Q17**: Fill in a number so that the program displays ```Second```.

# %%
num =  12    # fill in the value here
if num < 10 or num > 15:
    print('First')
else:
    if num % 2 == 0 and num <= 13:
        print('Second')
    else:
        print('Third')
# Out:
# Second

# %% [markdown]
# **Q18**: Even or Odd?
#
# Write a program that receives a number from the user and prints 'Even' if the number is even, and prints 'Odd' if the number is odd.
#
# Hint: You can use ```% 2``` to determine if a number is even or odd.
#
# Example 1:
# ```
# >Enter your number: 31
# Odd
# ```
# Example 2:
# ```
# >Enter your number: 24
# Even
# ```

# %%
number= "Enter yor number"
num = float(input(number))
if num % 2 ==0:
   print("even")
else:
   print("odd")

# %% [markdown]
# **Q19**: Date formatting
#
# Write a program that receives day, month, year, and format ('US', 'JP', 'TH') from the user and prints the date according to the format as follows:
#
# - The 'US' format = Month Day Year.
#
# - The 'JP' format = Year Month Day.
#
# - The 'TH' format = Day Month Year.
#
# Input:
#
# - Number, day
# - Number, month
# - Number, year
# - String, format
#
# Output:
# - Date format as specified
#
# Example 1:
# ```
# >Enter day: 1
# >Enter month: 10
# >Enter year: 2024
# >Enter format: US
# Month 10 Day 1 Year 2024
# ```
#
# Example 2:
# ```
# >Enter day: 1
# >Enter month: 10
# >Enter year: 2024
# >Enter format: JP
# Year 2024 Month 10 Day 1
# ```
#
# Example 3:
# ```
# >Enter day: 1
# >Enter month: 10
# >Enter year: 2024
# >Enter format: TH
# Day 1 Month 10 Year 2024
# ```

# %%
Day = int(input("Enter day"))
Month = int(input("Enter month"))
Year = int(input("Enter year"))
Format = input("enter format")
if Format == "JP":
  print(f"Year {Year} Month {Month} Day{Day}")
elif Format == "US":
  print(f"Month {Month} Day{Day} Year {Year}")
elif Format == "TH":
  print(f"Day {Day} Month {Month} Year {Year}")

# %% [markdown]
# **Q20**: Cashier Program ver 2.
#
# Write a program that receives the quantity of products the customer is buying.
#
# The available products are: Donut, Cupcake, and Popcorn. Donut costs 10 baht per piece, Cupcake costs 20 baht per piece, and Popcorn costs 40 baht per piece. Calculate the total price and apply discounts according to the following conditions:
#
# If buying at least 20 donuts, get 20% off on donuts (discount applies only to donuts)
# If buying at least 10 cupcakes, get 10% off on cupcakes (discount applies only to cupcakes)
# Note: Both discounts can be applied together.
#
# **Input**:
#
# - Number of donuts, cupcakes, and popcorn as integers
#
# **Output**:
#
# - Price before discount with two decimal places
# - Price after discount with two decimal places
#
# **Requirements**:
# - Must use **Named Constants**
#
# Example
# ```
# >Enter the number of donut: 30
# >Enter the number of cupcake: 20
# >Enter the number of popcorn:  5
# The total payment befor discount is 900.00 baht.
# The payment after discount is 800.00 baht.
# ```
#
# ```
# >Enter the number of donut: 5
# >Enter the number of cupcake: 20
# >Enter the number of popcorn:  3
# The total payment befor discount is 570.00 baht.
# The payment after discount is 530.00 baht.
# ```
#
# ```
# >Enter the number of donut: 10
# >Enter the number of cupcake: 10
# >Enter the number of popcorn:  5
# The total payment befor discount is 500.00 baht.
# The payment after discount is 480.00 baht.
# ```

# %%
# Name Constants
DONUT_P = 10
CUPCAKE_P = 20
POPCORN_P = 40
donut = int(input("Enter the number of donut:"))
cupcake = int(input("Enter the number of cupcake:"))
popcorn = int(input("Enter the number of popcorn:"))
total_dp = DONUT_P * donut
total_cp = CUPCAKE_P * cupcake
total_pp = POPCORN_P * popcorn
total_bef = tdp + tcp + tpp

if DONUT_A >20:
  total_dp = total_dp*0.8
if CUBCAKE_A >= 10:
  total_cp = total_cp*0.9

total_af = total_dp + total_cp + total_pp

print(f"The payment before discount is {total_bef:.2f} bath")
print(f"The payment after discount is {total_aaf:.2f} bath")

# %% [markdown]
# ## Submission
# - File -> Download -> Download .ipynb
# - Upload to MS Teams
