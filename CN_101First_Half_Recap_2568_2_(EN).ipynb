# %% [markdown]
# <a href="https://colab.research.google.com/github/yongsa-nut/TU_CN101_68-2/blob/main/CN_101First_Half_Recap_2568_2_(EN).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # First Half Recap (EN)

# %% [markdown]
# **Q1**: Write the output of the program
#
# ```python
# x = 3
# y = 5
# a = x + y * (5 + 1)
# b = y + 16 // x
# print(x, a, b)
# ```

# %% [markdown]
# **Q2** Write the output of the program
#
# ```python
# numbers = [10, 20, 30, 40]
# result1 = numbers[0] + numbers[2]
# result2 = str(numbers[1]) + str(numbers[3])
# print(result1, result2)
# ```

# %% [markdown]
# **Q3**: Write the output of the program
# ```python
# a = 10
# if a > 5:
#   print('A',end='-')
# if a > 7:
#   print('B',end='-')
#   a = 1
# if a > 9:
#   print('C',end='-')
# else:
#   print('D')
# ```

# %% [markdown]
# **Q4**: Write the output of the program
#
# ```python
# lst1 = [1, 5, 7]
# lst2 = [12, 7, 4]
# x = (lst2[1] < lst1[1]) or (lst2[-1] < lst1[0])
# y = x and (10 != 20) and (10 == 10)
# if y:
#   print('A',end='-')
# elif x:
#   print('B',end='-')
# print('D')
# ```

# %% [markdown]
# **Q5**: Write the output of the program
# ```python
# total = 0
# for i in range(1, 7, 2):
#   total += i
# for j in range(4 , 3, -1):
#   total += j
# print(i, j, total)
# ```

# %% [markdown]
# **Q6**: What will the program output if the user enters 5, 10, 15 in order? Write only the last print statement output.
# ```python
# numbers = [1, 2, 3, 4, 5, 6]
# numbers[0] = int(input('Enter a number: '))
# numbers[2] = int(input('Enter a number: '))
# numbers[-1] = int(input('Enter a number: '))
# print(numbers)
# ```

# %% [markdown]
# **Q7**: Write the output of the program
# ```python
# my_list = [1]
# your_list = [10,12,14]
# lst1 = my_list*3
# lst2 = my_list*2 + your_list
# print(lst1)
# print(lst2)
# ```

# %% [markdown]
# **Q8**: Write the output of the program
#
# ```python
# n = 3
# list1 = [0]*n
# list2 = [1]*n
# list3 = list1+list2
# for i in range(len(list3)):
#   list3[i] = list3[i]+3
# print(list3)
# ```

# %% [markdown]
# **Q9**: Write the output of the program
# ```python
# total = 0
# for i in range(5, 1, -2):
#   for j in range(2, 3, 1):
#     total += (i*j)
# print(total)
# ```

# %% [markdown]
# **Q10**: Write the output of the program
# ```python
# count = 0
# lst_a = [2, 4, 6]
# n = len(lst_a)
# for i in range(n):
#   for j in [3, 5, 7]:
#     if lst_a[i] > j//2:
#       count += 1
# print(count)
# ```

# %% [markdown]
# **Q11**: Fill in the code to calculate $z = \frac{(x+1)^2}{2(y-1)^3}$.
#
# Then print the answer according to the example below
# ```
# z = 0.12
# ```

# %%
x = 3
y = 5
z = ________________________
print(f"z = {z:______}")

# %% [markdown]
# ## Programming

# %% [markdown]
# **Q12**: Area and Circumference of a circle
#
# Write a program to calculate the area of a circle ($\pi r^2$) and the circumference ($2\pi r$). Set $\pi$ to 3.14.
#
# **Input**:
# - A real number, radius
#
# **Output**:
# - Area with three decimal places
# - Circumference with three decimal places
#
# **Requirements**:
# - Must use Named constant
#
# Example run:
# ```
# Enter radius: 10
# The area is 314.000
# The circumference is 62.800
# ```

# %% [markdown]
# **Q13**: Electricity bill
#
# Calculate the electricity bill based on progressive rates with the following details:
# Electricity bill = units used x electricity rate (according to table below) + monthly service fee
#
# The electricity rate is progressive as follows:
#
# | Units used (kWh) | Electricity rate (baht/unit) |
# |-----------------|---------------------|
# | 0-50            | 3.25                |
# | 51-100          | 4.00                |
# | 101 and above   | 4.50                |
#
# ---
#
# **Calculation examples:**
#
# Assuming monthly service fee = 38.22 baht
#
# **Calculation example 1**:
#
# - Units used: 45 kWh
#
# - Electricity bill = (45 x 3.25) + 38.22 = 184.47 baht
#
# **Calculation example 2**:
#
# - Units used: 80 kWh
#
# - Electricity bill = (50 x 3.25) + (30 x 4.00) + 38.22 = 320.72 baht
#
# **Calculation example 3**:
#
# - Units used: 150 kWh
#
# - Electricity bill = (50 x 3.25) + (50 x 4.00) + (50 x 4.50) + 38.22 = 625.72 baht
#
#
# Write a program to calculate the electricity bill from the units used.
#
# **Input**:
# - Real number, units used
# - Real number, monthly service fee
#
# **Output**:
# - Total electricity bill with two decimal places
#
# **Example: 1**
# ```
# Units: 45
# Monthly service fee: 25
# Bill: 171.25
# ```
#
# **Example: 2**
# ```
# Units: 150
# Monthly service fee: 38.22
# Bill: 625.72
# ```

# %% [markdown]
# **Q14**: Building a list of numbers from the user
#
# In this problem, we will write a program to receive n numbers from the user and create a list of numbers, then display the resulting list. The user will first enter the count of numbers (n), then enter n integers.
#
# **Input**:
# - n, an integer specifying how many numbers to enter
# - n more integers
#
# **Output**:
# - The created list
#
# **Requirements**:
# - n must be between 1 and 10. If user enters an invalid number, keep asking until valid
# - Must use Named constant
# - Must fill in only the given lines, no extra lines allowed
#
# Example 1:
# ```
# n = 3
# Enter a number: 1
# Enter a number: 3
# Enter a number: 5
# [1, 3, 5]
# ```
#
# Example 2:
# ```
# n = 20
# n is out of range.
# n = -5
# n is out of range.
# n = 5
# Enter a number: 20
# Enter a number: 5
# Enter a number: 7
# Enter a number: -5
# Enter a number: -8
# [20, 5, 7, -5, -8]
# ```

# %%
# Name constant
_______________
_______________

# Input Validation
n = __________________________________
while ________________________________:
    print('n is out of range.')
    __________________________________

# Initial list
numbers = [0] * n

# Receive n numbers from the user
for i in __________:
   numbers[i] = _________________________

# Output
______________

# %% [markdown]
# **Q15**: FizzBuzz v0.7
#
# Write a program to count numbers from the user that are divisible by 3, 5, and 15. The user will first enter the count of numbers (n), then enter n integers.
#
# **Input**:
# - n, an integer specifying how many numbers to count
# - n more integers
#
# **Output**:
# - Count of numbers divisible by 3
# - Count of numbers divisible by 5
# - Count of numbers divisible by 15
#
# Example 1:
# ```
# n = 3
# Enter a number: 1
# Enter a number: 5
# Enter a number: 10
# Divisible by 3 = 0
# Divisible by 5 = 2
# Divisible by 15 = 0
# ```
#
# Example 2:
# ```
# n = 5
# Enter a number: 3
# Enter a number: 5
# Enter a number: 10
# Enter a number: 15
# Enter a number: 27
# Divisible by 3 = 3
# Divisible by 5 = 3
# Divisible by 15 = 1
# ```
