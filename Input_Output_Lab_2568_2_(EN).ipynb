# %% [markdown]
# <a href="https://colab.research.google.com/github/yongsa-nut/TU_CN101_68-2/blob/main/Input_Output_Lab_2568_2_(EN).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Input Output Lab (EN)

# %% [markdown]
# For Google Colab:
#
# - Turn off AI: Tools -> Settings -> Hide generative AI features

# %% [markdown]
# **Q1**: What is the output of the code below? Write your answer in the code block below.
#
# จงเขียนผลลัพท์ที่ได้จากการทำงานของโค็ดด้านล่าง เขียนไว้ในช่อง code ด้านล่าง
#
# ```python
# print("House")
# ```

# %%
House # ใส่คำตอบตรงนี้ ไม่ต้องกดรัน (Put your answer here. Don't need to run)

# %% [markdown]
# **Q2**: What is the output?
#
# ```python
# print('Cat')
# print('Dog')
# print('Apple')
# ```

# %%
# ใส่คำตอบตรงนี้ ไม่ต้องกดรัน (Put your answer here. Don't need to run)

# %% [markdown]
# **Q3**: What is the output?
#
# ```python
# x = 5
# y = 3
# print(x + y)
# ```

# %% [markdown]
# **Q4**: What is the output?
#
# ```python
# a = 10
# b = 3
# print(a // b)
# print(a % b)
# ```

# %% [markdown]
# **Q5**: What is the output?
#
# ```python
# x = (5%2) + 3
# print(x)
# ```

# %% [markdown]
# **Q6**: What is the output?
#
# ```python
# a = 4
# b = 0
# c = 3
# a = a + 1
# b = b + 2
# result = a * b ** c
# print("The result is", result)
# ```

# %% [markdown]
# **Q7**: What is the output?
#
# ```python
# a = 1
# b = 2
# result = a + b + 1
# print(result)
# a = 3
# b = 4
# result = a + b + 1
# print(result)
# ```

# %% [markdown]
# **Q8**: What is the output?
#
# ```python
# a = 0
# a = a + 1
# print(a)
# a = a + 2
# a = a + 3
# print(a)
# ```

# %% [markdown]
# **Q9**: What is the output?
#
# ```python
# money = 57
# ten_coins = 57//10
# remaining = 57%10
# five_coins = remaining//5
# print(ten_coins, five_coins)
# ```

# %% [markdown]
# **Q10**: Fill in the blank so that the program prints out 10:

# %%
x = ___  # Fill here
print(x + 2)
# Out:
# 10

# %% [markdown]
# **Q11**: Complete the code to print as show below:
# ```python
# Happy
# Hello World!!
# ```

# %%
print(______)  # Fill here
print(______)  # Fill here

# %% [markdown]
# **Q12**: Fill in the code to calculate the area of a rectangle from the length and width stored in the variables ```length``` and ```width```

# %%
length = 5
width = 3
area = ______________  # Fill here
print(area)     #The answer should be 15

# %% [markdown]
# **Q13**: Fill in the code to calculate $7^3$:

# %%
result =   # Fill here
print(result)  # should print out 343

# %% [markdown]
# **Q14**: Fill in the code to find the remainder of dividing 17 by 5 and the quotient (integer division) of dividing 17 by 5

# %%
quotient = 17 ____ 5
remainder = 17 ____ 5
print(quotient, remainder) # should print out 3 2

# %% [markdown]
# **Q15**: Fill in the blank with mathematic operators so that the output is
# ```
# 8
# 5
# ```

# %%
x = 85
y = x ___ 10
z = x ___ 10
print(y)
print(z)

# %% [markdown]
# **Q16**: Fill in the code to calculate the average of a, b, c

# %%
a = 10
b = 15
c = 20
average = ________________  # Fill here.
print("The average is", average)

# %% [markdown]
# **Q17**: Fill in the code to receive an integer from the user and display the result as shown below
#
# ```
# Enter your number: 5
# Your squared number is 25
# ```

# %%
prompt = 'Enter your number'
num = int(______(prompt))
num_squared = num**2
print(f'Your squared number is {num_squared}')

# %% [markdown]
# **Q18**: Write a program that asks the user to enter two numbers and displays the sum of those two numbers as shown in the example below
#
# For example
# ```
# >Enter the first number: 3
# >Enter the second number: 5
# The sum of 3 and 5 is 8
# ```
# Note: `>` indicates the input line

# %%
first = ______________________
second = ______________________
total = first + second
print('The sum of', first, 'and', second, 'is', total)

# %% [markdown]
# **Q19**: Temperature Convertor
#
# Write a program that takes in a temperature in Fahrenheit (F) from the user as a real number (float) and convert it into Celsius (C) and print it out.
#
# จงเขียนโปรแกรมที่รับข้อมูลอุณหภูมิในหน่วย Fahrenheit (F) จากผู้ใช้งานเป็นตัวเลขจำนวนจริง (float) และ เปลี่ยนเป็น หน่วย Celsius (C) และแสดงผลออกมา
#
# The formula to convert F to C is C = $(F-32) \times 5/9$.
#
# Example 1:
# ```
# >Enter Fahrenheit: 32
# 0.0
# ```
#
# Example 2:
# ```
# >Enter Fahrenheit: 100
# 37.77777777777778
# ```

# %%
# 1) Input: Ask user for temperature in Fahrenheit


# 2) Process: Calculate temperature in Celsius


# 3) Output: Print the value out

# %% [markdown]
# **Q20**: Student Average GPA
#
# Write a program that receives three real numbers for Math, Science, and English GPA. Then calculate the average GPA and display the result as shown in the example.
#
# **Input**:
# - Math, Science, English GPA. Real number
#
# **Output**:
# - Average GPA
#
# Example 1:
# ```
# >Math GPA: 3
# >Science GPA: 3.5
# >English GPA: 3.75
# Average GPA is 3.4166666666666665
# ```
#
# Example 2:
# ```
# >Math GPA: 4
# >Science GPA: 2
# >Englishg GPA: 2.5
# Average GPA is 2.8333333333333335
# ```

# %% [markdown]
# **Q21**: Quadratic Equation
#
# Write a program that receives four real numbers $A, B, C, x$ and calculates the value according to the quadratic equation $y = Ax^2 + Bx +C$. Then display the value of $y$ as shown in the example.
#
# **Input**:
# - A, B, C, x as **real numbers** (```float```)
#
# **Output**:
# - y
#
# Example 1:
# ```
# >Enter A: 2
# >Enter B: 2
# >Enter C: 3
# >Enter x: 1
# y = 7
# ```
#
# Example 2:
# ```
# >Enter A: 1.5
# >Enter B: 2.4
# >Enter C: 0
# >Enter x: 2.5
# y = 15.375
# ```

# %% [markdown]
# ## Submission Instructions
#
# - Go to File -> Download -> Download .ipynb
# - Upload to Microsoft Teams
