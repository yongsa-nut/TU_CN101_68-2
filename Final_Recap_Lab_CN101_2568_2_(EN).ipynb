# %% [markdown]
# <a href="https://colab.research.google.com/github/yongsa-nut/TU_CN101_68-2/blob/main/Final_Recap_Lab_CN101_2568_2_(EN).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Final Lab (EN)

# %% [markdown]
# **Full name as appear in MS Teams**

# %% [markdown]
# **Q1**: Write the output of the following program
#
# ```python
# my_list = [10, 50, 30, 5, 7]
# your_list = [num*2 for num in my_list]
# print(min(your_list), max(your_list))
# ```

# %% [markdown]
# **Q2**: Write the output of the following program
#
# ```python
# jobs = ['Engineer','Accountant','Doctor']
# print(sum([len(job) for job in jobs]))
# ```

# %% [markdown]
# **Q3**: Write the output of the following program
#
# ```python
# list1 = "aa bb cc".split()
# list1.append("xx")
# list1[0] = "k"
# print(list1)
# ```

# %% [markdown]
# **Q4**: Write the output of the following program
#
# ```python
# temp = "10:20"
# words = temp.split(":")
# first = int(words[0])
# second = int(words[1])
# print(first+second)
# ```

# %% [markdown]
# **Q5**: Write the output of the following program
#
# ```python
# def do_something(total, rate=0.8):
#     return total+5*rate
#
# print(do_something(10)+do_something(10,0.1)*2)
# print(do_something(rate=0.3, total=5))
# ```

# %% [markdown]
# **Q6**: Write the output of the following program
#
# ```python
# my_string = "Hello"
#
# def do_another():
#     my_string = "Hello There"
#     my_string = my_string[7:]
#     print(my_string, end='')
#
# do_another()
# do_another()
# print(my_string)
# ```

# %% [markdown]
# **Q7**: Fill in the blank so that the program displays `AT MEOW`

# %%
cat = "Dog"
dog = "Cat"
text = cat + " " + dog + " Meow"
text = text.upper()
print(text[_____________])

# %% [markdown]
# **Q8**: Write the output of the following program
#
# ```python
# my_dict = {'Alice':10, 'Bob':20, 'Chris':30}
# my_dict['Pat'] = 50
# my_dict['Alice'] = 99
# print(my_dict)
# ```

# %% [markdown]
# **Q9**: Write the output of the following program
#
# ```python
# scores = {"Bob":23, "Big": 22, "bat":20, "Kate":17}
# total = 0
# for key, value in scores.items():
#     if (key[0].lower() == 'b') and (value%2==0):
#         total+= value
# print(total)
# ```

# %% [markdown]
# **Q10**: Write the output of the following program
#
# ```python
# my_list   = [2, 5, 3, 6]
# your_list = [my_list[i] for i in range(len(my_list)) if my_list[i]%2==0]
# for num in your_list:
#   my_list.append(num)
# print(my_list)
# print(my_list[-1]+len(my_list))
# ```

# %% [markdown]
# **Q11**: จงเขียนผลลัพท์ของโปรแกรมต่อไปนี้
#
# ```python
# bs = {'A':1, 'B':2, 'C':3}
# x = sum(bs.values())
# t = sum(v for v in bs.values() if v%2==1)
# if x == t:
#   print('yes')
# else:
#   print('no')
# ```

# %% [markdown]
# **Q12**: Circle Properties
#
# Write a function `circle_properties(radius)` that receives the radius of a circle and returns the area and circumference of the circle.
#
#
# **Input** (in `main`):
# - Real number, radius received from the user
#
# **Output** (in `main`):
# - Real number, area of the circle displayed to 2 decimal places
# - Real number, circumference displayed to 2 decimal places
#
# **Note**:
# - Use the value of pi from the math library
#
# Example 1:
#
# ```
# Enter the radius: 1
# Area: 3.14
# Circumference: 6.28
# ```
#
# Example 2:
# ```
# Enter the radius: 2.5
# Area: 19.63
# Circumference: 15.71
# ```

# %%
# import
_____________________________

# Implement circle_properties(radius) function here
# Argument: radius
# Returns: area and circumference
def circle_properties(radius):
    area = ____________________
    circum = __________________
    ___________________________

def main():
    radius = float(input("Enter the radius: "))
    # call circle_properties(radius) below
    ____________________________
    # print area and circumference
    ____________________________
    ____________________________

main()

# %% [markdown]
# # 13. Step count
#
# Fill in the code on the answer sheet to complete the program. The program reads a list of items from the user (where some items may be words such as `ten`, `twenty`, `five` which must be skipped and not included in the calculation), then computes the average, finds the position of the maximum value, and finds the position of the minimum value.
#
# ## Function Specifications
#
# **`get_input()`**: Reads a string from the user containing items separated by colons (`:`). Check each item with `.isdigit()` first — if it is a valid integer, convert it to `int` and append it to the list. Finally, return the list of filtered numbers.
#
# **`analyze(numbers)`**: Returns the average (computed on a single line using `sum()/len()`), the index of the maximum value, and the index of the minimum value, in that order. If there are duplicate values, select the last occurrence.
#
# **`print_answer(numbers, avg, max_i, min_i)`**: Prints 3 lines, where `Position` starts from 1 (not 0), and the average is displayed with 2 decimal places.
#
# **`main()`**: Calls the other functions in the correct order.
#
# ## Input
# A single line containing items separated by colons (`:`), with at least one valid integer.
#
# ## Output
# 3 lines as produced by `print_answer`.
#
# ### Example 1
# ```
# Enter numbers: 10:twenty:30:40:fifty
# Average: 26.67
# Highest: Position 3 (40)
# Lowest: Position 1 (10)
# ```
#
# ### Example 2
# ```
# Enter numbers: 100:200:300
# Average: 200.00
# Highest: Position 3 (300)
# Lowest: Position 1 (100)
# ```
#
# ### Example 3
# ```
# Enter numbers: 5:four:8:3:two:10:seven
# Average: 6.50
# Highest: Position 4 (10)
# Lowest: Position 3 (3)
# ```

# %%
def get_input():
    input_string = _________________________________
    raw = __________________________________________
    numbers = []
    for item in raw:
        if ________________________________________:
            item = ________________________________  # string to int
            numbers.append(____________________)
    return numbers


def analyze(numbers):
    avg = ___________________________________________

    max_i = 0
    min_i = 0
    for i in range(len(numbers)):
        if numbers[i] == max(numbers):
            max_i = i
        if _____________________________________:
            min_i = i

    ____________________________________________________


def print_answer(numbers, avg, max_i, min_i):
    print(___________________________________________)
    print(___________________________________________)
    print(___________________________________________)


def main():
    numbers = get_input()
    _______________________________________________
    _______________________________________________


main()

# %% [markdown]
# **Q14**: String to a list of squared numbers
#
# Create a function `get_query` that asks the user for a sequence of numbers separated by `//`. Then return a list of squared numbers. The list must pass these two conditions:
#
# 1) Length must not exceed 5
# 2) Numbers after squaring must not exceed 100
#
# You must call the function `is_valid_sequence` to check both conditions above.
#
# **Pseudocode**:
#
# 1. `is_valid_sequence(sequence)`: The function receives a list of numbers and returns True if the list meets both conditions, returns False if it fails either one.
# 2. `get_query()`: The function receives input from the user, converts the string to a list of squared numbers, then calls `is_valid_sequence` to check. If true, return the list. If not true, display "Invalid" and return None.
# 3. `main()`: The main function calls `get_query()` in a while loop. If the result is not None, break out of the loop and display the result. If it is None, continue calling `get_query()`.
#
#
# **Input**:
# - A string, which is a sequence of numbers separated by `//`
#
# **Output**:
# - A list of numbers
#
# **Requirements**:
# - Must use Named Constant
#
# Example 1:
# ```
# Enter numbers: 10//20//30
# The sequence is [100, 400, 900] and it's invalid.
# Enter numbers: 5//10
# A valid sequence: [25, 100]
# ```
#
# Example 2:
# ```
# Enter numbers: 5//10//1//2//3//4
# The sequence is [25, 100, 1, 4, 9, 16] and it's invalid.
# Enter numbers: 1//2//3//4
# A valid sequence: [1, 4, 9, 16]
# ```

# %%
# Named Constant
MAX_LENGTH = 5

def is_valid_sequence(sequence):
    if ________________:
        return False
    for num in sequence:
        if _______________
            ______________
    # exiting the loop means all numbers are not over 100
    return ____________

def get_query():
    seq = input('Enter numbers: ')
    # Fill in your code below
    str_list = _________________________
    squared_list = []  # list to store squared numbers
    for num_str in str_list:
        num = ___________________
        _____________________________ # add squared number to the list
    if __________________________
        _________________________
    else:
        _________________________
        return None

def main():
    while True:
        your_list = get_query()
        if __________________________:
            break
    print(f'A valid sequence: {your_list}')

main()

# %% [markdown]
# **Q15**: Linear function
#
# In this problem, we will create two data sets `X` and `Y`, where each `y` equals `y = w*x+b` (a straight line). The values `w` and `b` will be received from the user, and `x` will be generated by randomly generating integers between 1 and 8.
#
# After creating the data, find the sum of squares of all data for both X and Y, and the difference between those two sums, then display all three values.
#
# The functions to write are as follows:
#
# **gen_data(w, b, n)**: Function to create data `X` and `Y`
# - Create an empty list named `X`
# - Create an empty list named `Y`
# - Loop `n` times
#   - Create variable `x` to store a random number between 1 and 8
#   - Calculate `y` using the linear function `y = w*x + b`
#   - Add `x` to `X`
#   - Add `y` to `Y`
# - Return `X` and `Y`
#
# **sum_squared_diff(X,Y)**: Function to find the sum of squares of X, Y and find the difference of the sum of squares
# - Create variable `total_X` and set to 0
# - Create variable `total_Y` and set to 0
# - Loop i from 0 to the number of elements/length of X:
#   - Add the squared value of `X[i]` to `total_X`
#   - Add the squared value of `Y[i]` to `total_Y`
# - Return three values: `total_X`, `total_Y`, difference between `total_X` and `total_Y`
#
# **Function: main()**
# - Set random seed to 100
# - Receive `w`, `b`, `n` from the user
# - Call `gen_data` with `w`, `b` and `n` to create data `X` and `Y`
# - Call `sum_squared_diff` with `X` and `Y` and store the three returned values in variables `X_ss`, `Y_ss`, `XY_diff`
# - Display values `X_ss`, `Y_ss`, `XY_diff` as shown in the examples below
#
# **Note**:
# - Must follow the Pseudocode
#
# Example 1:
#
# ```
# Enter w: 2
# Enter b: 3
# Enter n: 5
# SSX = 195, SSY = 1173.0, Diff = -978.0
# ```
#
# Example 2:
#
# ```
# Enter w: -2
# Enter b: 1
# Enter n: 3
# SSX = 137, SSY = 475.0, Diff = -338.0
# ```

# %%
# import
___________________________


def gen_data(w, b, n):
    _______________________
    _______________________
    _______________________
    _______________________
    _______________________
    _______________________
    _______________________
    _______________________

def sum_squared_diff(X,Y):
    _______________________
    _______________________
    _______________________
    _______________________
    _______________________
    _______________________

# implement main function
def main():
    random.seed(100)
    w = float(input('Enter w: '))
    b = float(input('Enter b: '))
    n = int(input('Enter n: '))
    _______________________________________
    _______________________________________
    _______________________________________

main()
