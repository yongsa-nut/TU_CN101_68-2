# %% [markdown]
# <a href="https://colab.research.google.com/github/yongsa-nut/TU_CN101_68-2/blob/main/Repetition_Structure_and_List_Lab_2568_2_(EN).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Repetition Structure and List 1 Lab (EN)

# %% [markdown]
# ### **Using AI will result in 0**
#
# - Turn off AI: Tools -> Settings -> AI Assistance -> Hide Generative AI Features

# %% [markdown]
# **Q1**: What is the output of this program?
# ```python
# my_list = [1,2,3,4,7,12]
# print(my_list[0], my_list[2], my_list[-1])
# ```

# %% [markdown]
# **Q2**: What is the output of this program?
# ```python
# numbers = [1, 2, 3, 4, 5]
# for num in numbers:
#     print(num * 2, end=" ")
# ```

# %% [markdown]
# **Q3**: What is the outout of this program?
# ```python
# sequences = [7, 9, 10, 12]
# for i in range(len(sequences)):
#     print(f'{i} {sequences[i]}')
# ```

# %% [markdown]
# **Q4**: What is the output?
#
# ```python
# numbers = [10, 11, 12, 13]
# for i in range(len(numbers)):
#     print(f'{i+1}: {1+numbers[i]*2}')
# ```

# %% [markdown]
# **Q5**: What is the output?
#
# ```python
# numbers = [-5, 0, 3, 2, 10]
# count = 0
# n = len(numbers)
# for i in range(n):
#     if numbers[i] < i:
#         count += 1
# print(count)
# ```

# %% [markdown]
# **Q6**: What is the output?
#
# ```python
# total = 1
# somethings = [1, 2, 3, 1, 2, 3]
# for i in range(1, 6, 2):
#     total *= somethings[i]
# print(total)
# ```

# %% [markdown]
# **Q7**: What is the output of this program?
#
# ```python
# words = ['AAA','BBB','CCC','DDD','FFF']
# for i in range(len(words)):
#     if words[i] != 'BBB':
#         print(words[i], end=',')
#     if words[i] == 'DDD':
#         break
# ```

# %% [markdown]
# **Q8**: What is the output of this program?
# ```python
# numbers = [1, 2, 3, 4]
# numbers[1] = numbers[0] + numbers[1]
# numbers[2] = numbers[1] + numbers[2]
# numbers[3] = numbers[2] + numbers[3]
# print(numbers)
# ```

# %% [markdown]
# **Q9**: What is the output of this program?
# ```python
# seq1 = [1,2,3,4]
# n1 = len(seq1)
# seq2 = [323,1234,123156311]
# n2 = len(seq2)
# print(n1, n2)
# ```

# %% [markdown]
# **Q10**: What is the output of this program?
# ```python
# my_list = [3, 5, 7, 10, 12, 14, 19]
# mode = 'Delta'
# count = 0
# if mode == 'Alpha':
#     for num in my_list:
#         if num%2 == 0:
#             count += 1
# if mode == 'Delta:
#     for i in range(len(my_list)):
#         if my_list[i]%2 == 1:
#             count += 1
# print(count)
# ```

# %% [markdown]
# **Q11**: What is the output of this program?
#
# ```python
# total = 0
# for i in [2, 3]:
#     for j in [1,2]:
#       total += i*j
# print(total)
# ```

# %% [markdown]
# **Q12**: Fill in the blank to print the index and value of each element:
# ```
# 1: apple
# 2: banana
# 3: cherry
# ```

# %%
fruits = ["apple", "banana", "cherry"]
for i in range(1, _____):
    print(f"{i}: {fruits[__]}")

# %% [markdown]
# **Q13**: Complete the code to find the largest number in the list:
#
# Idea:
# - Have a variable (largest) to store the current maximum value
# - Then loop through all values in the list and compare with the current maximum
#   - If the value in the list is greater than the current maximum, it becomes the new maximum. So update the largest variable to that value

# %%
numbers = [3, 7, 2, 8, 1]
largest = numbers[0]
for num in numbers:
    if num __ largest:
        largest = _________
print(largest)

# %% [markdown]
# **Q14** Fill in the code to count numbers in `DATA` that are between 13 and 18 (inclusive of 13 and 18).

# %%
data = [0, 9, 14, 50, 32, 17, 20, 1]
count = 0
for num in data:
    if _______________:
        ______________
print(count)

# %% [markdown]
# **Q15**: Fill in the blank to count even numbers at an odd index in `my_list`
#
# Fill in the code to count even numbers that are at odd indices in `my_list`
#
# Explanation:
#
# The answer is 2.
# - Index 1 is 12
# - Index 5 is 4

# %%
my_list = [10, 12, 13, 13, 4, 4]
count = 0
for i in range(len(my_list)):
    if _______________________:
        count += 1
print(count)

# %% [markdown]
# **Q16**: Fill in the code to complete the program. The program will keep asking the user for input and perform actions based on the input as follows:
#
# 1.   `A` - print out `AAA`
# 2.   `B` - print out `BBB`
# 3.   `C` - terminate the program (exit the while loop)
#
# Example run 1:
# ```
# Option A: display AAA
# Option B: display BBB
# Option C: Terminate
# ---------------------
#
# Enter option: A
# AAA
#
# Option A: display AAA
# Option B: display BBB
# Option C: Terminate
# ---------------------
#
# Enter option: B
# BBB
#
# Option A: display AAA
# Option B: display BBB
# Option C: Terminate
# ---------------------
#
# Enter option: C
# Terminate
# ```

# %%
while True:
    print('\nOption A: display AAA')
    print('Option B: display BBB')
    print('Option C: Terminate')
    print('---------------------\n')
    option = input('Enter option: ')
    if option == 'A':
        print(____)
    ____________________:
        print("BBB")
    elif option == 'C':
        print('Terminate')
        _______
    else:
        print('Invalid Option')

# %% [markdown]
# **Q17** Package Shipment
#
# Write a program to calculate the total weight of packages and check if the total weight exceeds the cargo ship's capacity. Each package contains multiple items of the same type.
#
# For this problem, the program will first ask the user how many packages they want to enter. Then the user will input for each package: how many items are in it and the weight of each item (each package contains only one type of item).
#
# After the user enters all package information, finally the user will enter the weight limit that the ship can carry. If the total weight exceeds the limit, print 'Over limit'. If not, print 'Can carry'.
#
#
# Example 1
# ```
# >Enter the number of packages: 2
# >Enter the package 1 amount: 10
# >Enter the package 1 weight: 5
# >Enter the package 2 amount: 20
# >Enter the package 2 weight: 10
# The total weight is 250.00
# >Enter the weight limit: 300
# Can carry
# ```
#
# Example 2
# ```
# Enter the number of packages: 3
# Enter the package 1 amount: 1
# Enter the package 1 weight: 100
# Enter the package 2 amount: 5
# Enter the package 2 weight: 10
# Enter the package 3 amount: 10
# Enter the package 3 weight: 20
# The total weight is 350.00
# Enter the weight limit: 300
# Over weight
# ```

# %%
# Idea: Receive number of packages, then loop. In the loop, receive the quantity in the package and the weight

# %% [markdown]
# **Q18**: FizzBuzz ver 0.5
#
# Write a program to receive input from the user for which mode to use: `3` or `5`
#
# Then print the data in `numbers` with the following conditions:
#
# - If mode is `3` and the number is divisible by 3, print 'Fizz' along with that number.
#
# - If mode is `5` and the number is divisible by 5, print 'Buzz' along with that number.
#
# Finally, print how many numbers matched the condition.
#
# **Requirement**: Must validate that the user enters only '3' or '5'
#
#
# Example 1
# ```
# Enter mode (3 or 5): 3
# Fizz 3
# Fizz 9
# Fizz 30
# 3
# ```
#
# Example 2
# ```
# Enter mode (3 or 5): 7
# Mode is not 3 or 5.
# Enter mode (3 or 5): 9
# Mode is not 3 or 5.
# Enter mode (3 or 5): 5
# Buzz 5
# Buzz 10
# Buzz 20
# Buzz 30
# 4
# ```

# %%
numbers = [2, 3, 5, 10, 9, 20, 30, 7]

# Input Validation: Check that user enters only 3 or 5


# Process - Loop through numbers

# %% [markdown]
# ## Submission
# - File -> Download -> Download .ipynb
# - Upload to MS Teams
