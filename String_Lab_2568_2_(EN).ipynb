# %% [markdown]
# <a href="https://colab.research.google.com/github/yongsa-nut/TU_CN101_68-2/blob/main/String_Lab_2568_2_(EN).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # String Lab (EN)

# %% [markdown]
# **Q1**: What will the following code print out?
#
# ```python
# my_str = "Hello There, How are you?"
# print(my_str[0], my_str[5], my_str[10], my_str[-1])
# ```

# %% [markdown]
# **Q2**: What will the following code print out?
#
# ```python
# str1 = "Hello Where is this?"
# print(str1[3:7])
# print(str1[:4])
# print(str1[len(str1)-4:])
# ```

# %% [markdown]
# **Q3**: What will the following code print out?
#
# ```python
# seq = [5, 7, 9, 11, 6, 8, 10]
# print(seq[1:3], seq[-1:-3:-1])
# print(seq[4:])
# print(seq[::-1])
# ```

# %% [markdown]
# **Q4**: What will the following program print out?
#
# ```python
# her_string = 'How are you today?'
# his_string = 'I am doing well.'
# result = ('h' in her_string) or ('m' in his_string)
# print(result)
# ```

# %% [markdown]
# **Q5**: What will the following program print out?
# ```python
# texts = ['AAA', 'BBB', 'CCC']
# new_text = "-".join(texts)
# print(new_text)
# ```

# %% [markdown]
# **Q6**: What will the following program print out?
#
# ```python
# ref = "This"
# outcome = (ref*2).lower() + " " + ("SvD"*3).upper()
# print(outcome)
# ```

# %% [markdown]
# **Q7**: What will the following program print out?
#
# ```python
# chars = 'AAaaABbbCcCddd'
# total = 0
# for char in chars:
#     if char == 'A':
#         total += 1
#     if char == 'B':
#         total += 2
#     if char == 'C':
#         total += 3
# print(total)
# ```

# %% [markdown]
# **Q8**: What will the following program print out?
#
# ```python
# s = '  abcde  '
# temp = s.strip()
# print(temp)
# temp = temp.lstrip('a')
# print(temp)
# temp = temp.rstrip('e')
# print(temp)
# print(s.strip().lstrip('a').rstrip('e'))
# ```

# %% [markdown]
# **Q9**: What will the following program print out?
#
# ```python
# numbers = "One Two Three Four Five Six"
# one_index = numbers.find("One")
# five_index = numbers.find("Five")
# nine_index = numbers.find("Nine")
#
# print(one_index)
# print(five_index)
# print(nine_index)
# ```

# %% [markdown]
# **Q10**: What will the following program print out?
#
# ```python
# my_str = "One Two One Two one two one two"
# your_str = my_str.replace("One","1")
# his_str = your_str.replace('e',"E")
# print(your_str)
# print(his_str)
# ```

# %% [markdown]
# **Q11**: What will the following program print out?
#
# ```python
# str1 = "10//20//30//40"
# temp = str1.split("//")
# print(temp)
# x = int(temp[0])
# y = int(temp[3])
# print(x+y)
# print(temp[0]+temp[3])
# ```

# %% [markdown]
# **Q12**: What will the following program print out?
#
# ```python
# target1 = "12345"
# target2 = "abc44"
# target3 = "ABcc"
#
# print(target1.isdigit())
# print(target2.isdigit())
# print(target3[:2].isupper())
# print(target2[3:].isdigit())
# ```

# %% [markdown]
# **Q13**: What will the following program print out?
#
# ```python
# temp = '1 2 3 4 5'
# temp = temp.split(' ')
# x = 0
# y = ''
# for num in temp:
#     x += int(num)
#     y += num
# print(x, y)
# ```

# %% [markdown]
# **Q14**: Fill in the blank so that the program print out $\texttt{Wrd}$

# %%
my_string = "Hello"
your_string = my_string + " World" + my_string
print(your_string[___])

# %% [markdown]
# **Q15**: Fill in the blank so that the program print out `Hello Alice, How are you? Today is Sunday.`

# %%
def print_thing(name, day):
    msg = f"Hello {____},"
    msg += f" How are you? "
    msg += f"_____________"
    print(msg)

print_thing("Alice", "Sunday")

# %% [markdown]
# **Q16**: Fill in the blank so that the program print out `['1', '2', '3', '4', '5']`

# %%
my_string = "1,2,3,4,5"
string_lst = __________________
print(string_lst)

# %% [markdown]
# **Q17**: Find the sum from a given string
#
# Write a function `sum_from_string(string)` that receives multiple numbers separated by spaces as a string, e.g., `10 30 50 10 31`, and returns the sum of all numbers. The `main` function is already provided which receives input from the user.
#
# Example 1:
# ```
# Enter numbers: 1 2 3 4
# Total = 10
# ```
#
# Example 2:
# ```
# Enter numbers: 10 30 50 10 31
# Total = 131
# ```

# %%
def sum_from_string(string):
    # Args: string - numbers separated by spaces as a string
    # Return: total - the sum of all numbers.
    # Fill in your code here

    return ...

def main():
    numbers = input('Enter numbers: ')
    total = sum_from_string(numbers)
    print(f'Total = {total}')

main()

# %% [markdown]
# **Q18**: Defanging an IP Address
#
# Write a function `defang(ip)` that receives an IP address (e.g., 1.1.1.1) and returns the defanged version where "." is replaced with "[.]". The `main()` function is already provided.
#
# **Extra**: Try solving this problem in more than one way.
#
#
# Example 1:
# ```
# Enter IP address: 1.1.1.1
# 1[.]1[.]1[.]1
# ```
#
# Example 2:
# ```
# Enter IP address: 255.100.50.0
# 255[.]100[.]50[.]0
# ```

# %%
def defang(ip):
    # Args: ip (string)
    # Returns: defanged ip (string)
    # fill in your code here

    return ...

def main():
    ip = input('Enter IP address: ')
    print(defang(ip))

main()

# %% [markdown]
# **Q19**: Check first and last
#
# Write a function `check_first_last(string, target)` that takes two strings: `string` and `target`, and returns two values: whether `string` starts with `target` (`True` or `False`) and whether `string` ends with `target` (`True` or `False`).
#
# **Requirements**
# - **Use slicing to solve this problem.** Think about how you can slice the beginning and end of `string` to have the same length as `target`.
# - The `main()` function is already provided.
#
# Example 1
# ```
# Enter string: Hello
# Enter target: He
# Start = True, End = False
# ```
#
# Example 2
# ```
# Enter string: ABCDDDABC
# Enter target: ABC
# Start = True, End = True
# ```

# %%
# Implement check_first_last(string, target) below
def check_first_last(string, target):
    # fill in your code below
    ...


def main():
    string = input('Enter string: ')
    target = input('Enter target: ')
    fst, lst = check_first_last(string, target)
    print(f'First = {fst}, Last = {lst}')

main()

# %% [markdown]
# **Q20**: Jewels and Stones
#
# Write a function `count_jewels(jewels, stones)` that takes two strings: `jewels` and `stones`, and counts how many `stones` are `jewels`. Here, `jewels` is a string of characters specifying which characters are jewels, and `stones` is a string of characters.
#
# Letters are case sensitive, so "a" and "A" are not the same.
#
# Example 1:
# ```
# Enter jewels: aA
# Enter stones aAAbbbb
# 3
# ```
# Explanation: There are two jewels, 'a' and 'A'. There is 1 'a' and 2 'A' in the stones so the total is 3.
#
# Example 2:
# ```
# Enter jewels: z
# Enter stones: ZZ
# 0
# ```
#
# Example 3:
# ```
# Enter jewels: kKp
# Enter stones: aaBkBcKcKcDDgkggkgpp
# 7
# ```

# %%
# implement count_jewels(jewels, stones) here
def count_jewels(jewels, stones):
    # Args:
    #    - jewels (string)
    #    - stones (string)
    # Return: a number
    ...

def main():
    jewels = input('Enter jewels: ')
    stones = input('Enter stones: ')
    print(count_jewels(jewels, stones))

main()
